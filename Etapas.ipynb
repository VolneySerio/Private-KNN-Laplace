# %% [markdown]
# ## Etapas da atividade
#
# -----------------------------------------

# %% [markdown]
# #### Modelo KNN
# <input type="checkbox" checked disabled>KNN<br>
# <input type="checkbox" checked disabled>KNN - breast<br>
# <input type="checkbox"  disabled>Modelo KNN treinado com adult-income<br>
# <input type="checkbox"  disabled>Criar modelo R-N<br>
# <input type="checkbox"  disabled>R-N<br>
#
# -----------------------------------------
#
# #### Dataset
# <input type="checkbox" checked disabled>Baixar dataset<br>
# <input type="checkbox" checked disabled>Dropar colunas<br>
# <input type="checkbox" disabled>Limpar dataset (?)<br>
# <input type="checkbox" disabled>Aplicar Encoding<br>
# <input type="checkbox" disabled>Explicar a escolha do encoding<br>
#
# -----------------------------------------
#
# #### Apresentação
# <input type="checkbox"  disabled>Pseudo-código do kNN<br>
# <input type="checkbox" disabled>Como codificou atributos não numéricos<br>
# <input type="checkbox" disabled>Qual valor de orçamento utilizado cada vez que utilizou o mecanismo de Laplace e o porquê<br>
# <input type="checkbox" disabled>Qual a sensibilidade global e o porquê?<br>
# <input type="checkbox" disabled>Gráfico de acurácia por cada valor de ε (colocar, também, como referência, a linha representando a acurácia do kNN sem privacidade).<br>
#
#
# -------------------------------------------

# %% [markdown]
# #### Qual a sensibilidade global e o porquê?

# %% [markdown]
# Sensibilidade é 1, pois a consulta é numérica.
