# %% [markdown]
# ## Etapas da atividade
#
# -----------------------------------------

# %% [markdown]
# #### Modelo KNN
# <input type="checkbox" checked >KNN<br>
# <input type="checkbox" checked >KNN - breast<br>
# <input type="checkbox"  >Modelo KNN treinado com adult-income<br>
# <input type="checkbox" checked >Criar modelo R-N<br>
# <input type="checkbox" checked>Adaptar retorno do algoritmo 1 para o do trabalho<br>
# <input type="checkbox"  >R-N<br>
#
# -----------------------------------------
#
# #### Dataset
# <input type="checkbox" checked >Baixar dataset<br>
# <input type="checkbox" checked >Dropar colunas<br>
# <input type="checkbox" >Limpar dataset (?)<br>
# <input type="checkbox" checked >Catalogar Encoding<br>
# <input type="checkbox" >Aplicar Encoding<br>
# <input type="checkbox" checked>Explicar a escolha do encoding<br>
#
# -----------------------------------------
#
# #### Apresentação
# <input type="checkbox"  >Pseudo-código do kNN<br>
# <input type="checkbox" >Como codificou atributos não numéricos<br>
# <input type="checkbox" >Qual valor de orçamento utilizado cada vez que utilizou o mecanismo de Laplace e o porquê<br>
# <input type="checkbox" >Qual a sensibilidade global e o porquê?<br>
# <input type="checkbox" >Gráfico de acurácia por cada valor de ε (colocar, também, como referência, a linha representando a acurácia do kNN sem privacidade).<br>
#
#
# -------------------------------------------

# %% [markdown]
# #### Qual a sensibilidade global e o porquê?
# Sensibilidade é 1, pois a consulta é numérica.
# #### Codificação dos atributos?
# OneHotEncoding, pois os atributos não possuem relação de hieraquia. Infelizmente, a maldição da dimensionalidade vai ocorrer nesse treinamento.
